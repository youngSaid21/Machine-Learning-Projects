# %% [markdown]
# # Data Exploration – Introverts vs Extroverts
#
# ### Project Overview
# This project is part of the Kaggle Playground Series 2025. The goal is to predict whether a person is an introvert or an extrovert based on their social behavior and personality traits. This challenge is a great opportunity to practice machine learning skills on a realistic and accessible dataset.
#
# dataset : https://www.kaggle.com/datasets/rakeshkapilavai/extrovert-vs-introvert-behavior-data/data
#
# ### Notebook Objective
# In this notebook, we will explore the provided dataset in order to:
# - Understand the structure and content of the data
# - Identify important variables
# - Detect any missing values or anomalies
# - Visualize distributions and relationships between variables
#
# This step is essential to guide the preprocessing and modeling phases that follow.

# %% [markdown]
# ### Importing Libraries and Loading Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/raw/train.csv')

df.head()
# Out:
#    id  Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0   0               0.0         No                      6.0            4.0
# 1   1               1.0         No                      7.0            3.0
# 2   2               6.0        Yes                      1.0            0.0
# 3   3               3.0         No                      7.0            3.0
# 4   4               1.0         No                      4.0            4.0
#
#   Drained_after_socializing  Friends_circle_size  Post_frequency Personality
# 0                        No                 15.0             5.0   Extrovert
# 1                        No                 10.0             8.0   Extrovert
# 2                       NaN                  3.0             0.0   Introvert
# 3                        No                 11.0             5.0   Extrovert
# 4                        No                 13.0             NaN   Extrovert

# %% [markdown]
# ### Information about Features

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18524 entries, 0 to 18523
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         18524 non-null  int64
#  1   Time_spent_Alone           17334 non-null  float64
#  2   Stage_fear                 16631 non-null  object
#  3   Social_event_attendance    17344 non-null  float64
#  4   Going_outside              17058 non-null  float64
#  5   Drained_after_socializing  17375 non-null  object
#  6   Friends_circle_size        17470 non-null  float64
#  7   Post_frequency             17260 non-null  float64
#  8   Personality                18524 non-null  object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 1.3+ MB

# %% [markdown]
# ### Descriptive statistics

# %%
df.describe()
# Out:
#                  id  Time_spent_Alone  Social_event_attendance  Going_outside  \
# count  18524.000000      17334.000000             17344.000000   17058.000000
# mean    9261.500000          3.137764                 5.265106       4.044319
# std     5347.562529          3.003786                 2.753359       2.062580
# min        0.000000          0.000000                 0.000000       0.000000
# 25%     4630.750000          1.000000                 3.000000       3.000000
# 50%     9261.500000          2.000000                 5.000000       4.000000
# 75%    13892.250000          4.000000                 8.000000       6.000000
# max    18523.000000         11.000000                10.000000       7.000000
#
#        Friends_circle_size  Post_frequency
# count         17470.000000    17260.000000
# mean              7.996737        4.982097
# std               4.223484        2.879139
# min               0.000000        0.000000
# 25%               5.000000        3.000000
# ...

# %%
df.describe(include='object')
# Out:
#        Stage_fear Drained_after_socializing Personality
# count       16631                     17375       18524
# unique          2                         2           2
# top            No                        No   Extrovert
# freq        12609                     13313       13699

# %%
### Missing Values
df.isnull().sum() / len(df) * 100
# Out:
# id                            0.000000
# Time_spent_Alone              6.424098
# Stage_fear                   10.219175
# Social_event_attendance       6.370114
# Going_outside                 7.914057
# Drained_after_socializing     6.202764
# Friends_circle_size           5.689916
# Post_frequency                6.823580
# Personality                   0.000000
# dtype: float64

# %%
import missingno as msno

# Bar chart des valeurs manquantes
msno.bar(df)

# Heatmap des corrélations entre valeurs manquantes
msno.heatmap(df)

# Dendrogramme des valeurs manquantes
msno.dendrogram(df)
# Out:
# <Axes: >

# %% [markdown]
# ## Summary of Data Exploration
#
# Through this initial data exploration, we have gained a better understanding of the dataset's structure and content. We identified the main features related to social behavior and personality, as well as the target variable for classification. Our analysis revealed that:
#
# - Most features contain some missing values, but these missing patterns appear to be independent across variables.
# - The categorical variables (such as "Stage_fear" and "Drained_after_socializing") will require encoding for further analysis.
# - The target variable "Personality" is complete and suitable for supervised learning.
# - No strong correlation was found between missing values of different features, which means we can handle missing data on a per-feature basis.
#
# This exploration step provides a solid foundation for the next phases: data preprocessing and more in-depth exploratory data analysis (EDA). The insights gained here will guide our choices for data cleaning, feature engineering, and modeling strategies.
